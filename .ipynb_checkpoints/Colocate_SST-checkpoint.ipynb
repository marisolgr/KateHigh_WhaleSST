# %%
# Modules
import warnings
warnings.simplefilter('ignore') # filter some warning messages

import numpy as np
import pandas as pd
import xarray as xr
from calendar import monthrange

# %%
dsa = xr.open_mfdataset('./OISSTa/OISST_*.nc')
iy=dsa['time.year'].min().data
fy=dsa['time.year'].max().data
dsa
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 14610, lat: 48, lon: 52)
# Coordinates:
#   * time     (time) datetime64[ns] 1982-01-01 1982-01-02 ... 2021-12-31
#   * lat      (lat) float32 31.12 31.38 31.62 31.88 ... 42.12 42.38 42.62 42.88
#   * lon      (lon) float32 232.1 232.4 232.6 232.9 ... 244.1 244.4 244.6 244.9
# Data variables:
#     anom     (time, lat, lon) float32 dask.array<chunksize=(1461, 48, 52), meta=np.ndarray>
# Attributes:
#     Conventions:    CF-1.5
#     title:          NOAA High-resolution Blended Analysis: Daily Values using...
#     institution:    NOAA/NCDC
#     source:         NOAA/NCDC  ftp://eclipse.ncdc.noaa.gov/pub/OI-daily-v2/
#     comment:        Reynolds, et al., 2007: Daily High-Resolution-Blended Ana...
#     history:        Tue Jan 25 17:17:57 2022: ncrcat -O -d lon,232.000000,245...
#     dataset_title:  NOAA Daily Optimum Interpolation Sea Surface Temperature
#     References:     https://www.psl.noaa.gov/data/gridded/data.noaa.oisst.v2....
#     NCO:            netCDF Operators version 4.8.1 (Homepage = http://nco.sf....

# %%
dsc = xr.open_dataset('./OISSTa/OISSTdV2_KateHigh_Cal.nc')
dsc.close()
dscm = dsc.resample(time='1M').mean(keep_attrs=True,skipna=False)
dscm
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 12, lat: 14, lon: 10)
# Coordinates:
#   * time            (time) object 0001-01-31 00:00:00 ... 0001-12-31 00:00:00
#   * lat             (lat) float32 36.62 36.88 37.12 37.38 ... 39.38 39.62 39.88
#   * lon             (lon) float32 236.1 236.4 236.6 236.9 ... 237.9 238.1 238.4
# Data variables:
#     sst             (time, lat, lon) float32 12.5 12.46 12.41 ... nan nan nan
#     valid_yr_count  (time, lat, lon) float32 29.0 29.0 29.0 29.0 ... 0.0 0.0 0.0
# Attributes:
#     Conventions:                    CF-1.5
#     title:                          NOAA High-resolution Blended Analysis: Da...
#     institution:                    NOAA/NCDC
#     source:                         NOAA/NCDC  ftp://eclipse.ncdc.noaa.gov/pu...
#     references:                     http://www.esrl.noaa.gov/psd/data/gridded...
#     comment:                        Reynolds, et al., 2007: Daily High-Resolu...
#     history:                        Created 2017/08/25 by doDayLTM64
#     not_missing_threshold_percent:  minimum 3% values input to have non-missi...

# %%
mam = pd.read_excel('stranding data for marisol.xlsx')
mam['SSTa (C)']=np.nan
mam['SST (C)']=np.nan
#list(mam)
# Out:
# ['Source',
#  'CAS Catalog Number',
#  'FieldNumber',
#  'Additional Identifier',
#  'Duplicate',
#  'Family',
#  'CommonName',
#  'Genus',
#  'Species',
#  'Name',
#  'affiliation',
#  'County',
#  'City',
#  'Locality',
#  'Inial Lat (starts 2018)',
#  'Initial Long (starts 2018)',
#  'Latitude',
#  'Longitude',
#  'Lat/Long Estimated',
#  'corrected by',
#  'date fixed',
#  'georeferencing notes',
#  'georeferenced longitude',
#  'georeferenced latitude',
#  'uncertainty raduis (m)',
#  'fixed Latitude',
#  'fixed Longitude',
#  'How fixed lat/long determined',
#  'georeferenced by',
#  'lat/long protocol',
#  'How Lat/Long Det',
#  'georeference verification',
#  'Confidence Code',
#  'GE#',
#  'SignsHumanInteraction',
#  'BoatCollision',
#  'Shot',
#  'FisheryInteraction',
#  'OtherHumanInter',
#  'HowDetermined',
#  'OtherCauses',
#  'CauseOfDeathOtherRemarks',
#  'DateOfInitialObs',
#  'First Observed',
#  'InitialStatus',
#  'Era',
#  'ExaminationDate',
#  'month',
#  'day',
#  'year',
#  'NoExam',
#  'ExamCondition',
#  'Sex',
#  'AgeClass',
#  'condition',
#  'CarcassType',
#  'StraightLength',
#  'SL_units',
#  'SL_estimated',
#  'Tag at Stranding',
#  'Tag_1_ID',
#  'Tag_1_Color',
#  'Tag_1_Type',
#  'Tag_1_Placement',
#  'Tag_2_ID',
#  'Tag_2_Color',
#  'Tag_2_Type',
#  'Tag_2_Placement',
#  'Disposal_Towed',
#  'Disposal_Sunk',
#  'SpecimenDisp_ScientificCollection',
#  'Necropsy Code',
#  'Necropsied',
#  'Necropsy Type',
#  'Carcass Type',
#  'NecropsiedDate',
#  'NecropsiedBy',
#  'Additional Remarks',
#  'Gear Collected',
#  'Gear Disposition',
#  'SSTa (C)',
#  'SST (C)']

# %%
for row in mam.iterrows():
    lats = row[1]['georeferenced latitude']
    lons = row[1]['georeferenced longitude']
    years = row[1]['year']
    months = row[1]['month']
        
    # colocate data
    fecha1 = str(years)+'-'+str(months).zfill(2)+'-01'
    edy = monthrange(years, months)[1]
    fecha2 = str(years)+'-'+str(months).zfill(2)+'-'+str(edy).zfill(2)
    #print(fecha1, fecha2)
    t = dsa.sel(lat=float(lats),lon=float(lons)+360, method='ffill', tolerance=0.3)
    t2 = t.sel(time=slice(fecha1,fecha2)).anom.mean()
    print('.')
    mam.at[row[0],'SSTa (C)'] = t2.values
    
    # values
    t3 = dscm.sel(lat=float(lats),lon=float(lons)+360, method='ffill', tolerance=0.3)
    t4 = t3.sst[months-1].values
    mam.at[row[0],'SST (C)'] = t2.values + t4
# Out:
# 1.8003227
# 11.744073
# 0.95516133
# 12.163893
# 1.7223332
# 12.205368
# -0.3029032
# 11.744073
# -1.8741937
# 11.77434
# 1.8419998
# 12.611987
# -2.616452
# 11.424494
# 0.69633335
# 12.611987
# 2.215
# 12.611987
# -0.23516126
# 12.232192
# 0.22199994
# 11.296356
# -0.6745161
# 14.362468
# 0.58064514
# 12.401913
# 0.58064514
# 12.401913
# -1.5564287
# 11.845147
# -0.5270966
# 13.320757
# 0.27766666
# 12.611987
# 1.7223332
# 12.205368
# 1.7223332
# 12.205368
# -1.2493333
# 10.868354
# 1.8776666
# 12.611987
# -0.75266665
# 10.868354
# -1.9567741
# 11.582447
# 0.15499999
# 12.968976
# -0.6786668
# 11.971342
# 3.3403225
# 13.320757
# 1.8419998
# 12.611987
# -0.68599993
# 10.868354
# -2.117742
# 11.77434
# -1.057742
# 11.123928
# -0.35967737
# 11.502112
# -0.534
# 11.401459
# 2.4432254
# 14.485673
# 2.4432254
# 14.485673
# 0.77035713
# 12.429224
# 0.77035713
# 12.429224
# 1.7223332
# 12.205368
# 0.039666664
# 11.410921
# -0.76666653
# 11.409138
# 0.3748387
# 11.325171
# -1.2987096
# 13.077553
# 1.8419998
# 12.611987
# 0.29333335
# 12.205368
# 1.0533333
# 12.205368
# 1.2423332
# 12.611987
# 1.2423332
# 12.611987
# 1.2590321
# 11.869611
# -1.7496773
# 10.735996
# -1.7496773
# 10.735996
# 0.93483865
# 14.485673
# 2.0882142
# 12.429224
# 0.49821424
# 12.429224
# -1.1800001
# 10.868354
# -0.6079999
# 12.611987
# -1.0716665
# 12.205368
# -1.0716665
# 12.205368
# -0.5212903
# 11.77434
# 0.29
# 13.345988
# -1.9426666
# 10.904344
# 0.555
# 11.296356
# -0.060645137
# 12.581123
# 3.3880644
# 13.889376
# 1.8419998
# 12.611987

# %%
mam[{'georeferenced longitude','georeferenced latitude','month','year','SSTa (C)'}]
mam.to_csv('stranding data collocated SST 29March2022.csv')
